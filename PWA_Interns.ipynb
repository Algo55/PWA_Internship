# %% [markdown]
# <a href="https://colab.research.google.com/github/Algo55/PWA_Internship/blob/main/PWA_Interns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bitcoin Trading AlgoRithim: Programming Worksheet for PWA Summer Internship -
# # Piece of Cake! :)
# ## Please Relax, I'm assuming you have ZERO programming experience. Programing is kinda like using formulas in excel.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Instead of using excel, we will use something called [Jupyter Notebooks](https://jupyter.org/), where we can write code in a programming language called [Python](https://www.python.org//). (The name comes from the TV show Monty Python, not the snake).
# ### Jupyter notebooks are used to share research by allowing us to combine executable code with regular text and charts and tables.
# ### Lets write our very first computer code.
# ### In the "code cell" below type print("Hello World!").
# ### Then press the play button on the left of the cell.

# %% [markdown]
# ### Ok, Now, lets download some python libraries we'll need. You don't need to  worry too much about this for now, unless you want to learn the Python programming language.

# %%
# Import the Python Libraries I will need
# Import a library called numpy which helps us work with lists of numbers like stock prices
import numpy as np

# Import pandas which helps us work with tables of data like excel worksheets
import pandas as pd 

# Import datareader which helps us steal, ...I mean... download data from the internet
import pandas_datareader as pdr

# Import matplotlyb to draw pretty pictures
import matplotlib.pyplot as plt

# Import datetime to deal with dates
import datetime as dt
from datetime import date

# %% [markdown]
# We need to get some data, otherwise this is going to be really boring. So lets steal some data from the U.S. Government!
# Lets set a start date and an end date for the data we want to use.

# %%
# We need to set the time period for our analysis
start_date = dt.datetime(2020, 1, 1)
end_date = dt.datetime.today()
end_date_str = str(date.today())

# %%
#  So lets steal,...download data from the U.S. Government
BitcoinPrice = pdr.get_data_fred('CBBTCUSD', start=start_date, end=end_date)

# %% [markdown]
# Lets check to see if we actually downloaded the data. In a code cell below type: print(BitcoinPrice)

# %% [markdown]
# Lets draw a pretty picture of our data:

# %% [markdown]
# Awesome!!  We have data to play with!

# %% [markdown]
# # Algorithim for [Momentum Trading](https://www.investopedia.com/trading/introduction-to-momentum-trading/)

# %% [markdown]
# They are commonly used by hedge funds.  One of the simplest trading strategies. They use moving averages of historical prices over different time periods or windows.
# Lets calculate a moving average for our price, say over 20 days. I am taking a 20-day window (period) and calculating the average price meaning add up all the prices and divide by 20.  Expressed in mathematical shorthand using [Latex & Markdown](https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd) language:

# %% [markdown]
# So what's actually going on here?  Lets print our historical price data for Bitcoin again over a 20-day window.

# %% [markdown]
# Lets write the code to calculate the 20-day moving average using python instead of doing it in excel

# %% [markdown]
# As an exercise now plot the data you have, meaning the price of bitcoin and the 20-day:

# %% [markdown]
# As an exercise, now calculate the 60-day moving average on your own, and include it in your table (Dataframe):

# %% [markdown]
# Print the Price of Bitcoin with its 20-day and 60-day moving averages

# %% [markdown]
# Plot the Bitcoin Price and it's 20-day and 60-day moving averages.

# %% [markdown]
# ### Trading Strategy:
# Propose a trading Strategy

# %%
# Print the bitcoin Price and Moving Average table to visualize your data and come up with a trading strategy.

# %% [markdown]
# ### Write code to implement your trading algorithim.

# %%
# Write your code here

# %% [markdown]
# # Great Job Everyone !!!
